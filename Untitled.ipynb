# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.options.display.max_rows = 100
pd.options.display.max_columns = 200

# %%
df = pd.read_excel('../input/case-data/Case data.xlsx')
delay_codes = pd.read_excel('../input/case-data/Case data.xlsx', sheet_name='Delay Group code')

# %%
df.head(1).T
# Out:
#                                                                      0
# schd_dep_date                                      2021-10-01 00:00:00
# flight_number                                                   OP0654
# reg                                                             A6-BMF
# fleet_family                                                      B787
# sub_fleet                                                      B787-10
# sched_dep_iata                                                     CAI
# dep_country                                                      Egypt
# dep_region                                                      Africa
# sched_arr_iata                                                     AUH
# arr_region                                                        Asia
# std_z                                                         10:35:00
# std_z_date                                         2021-10-01 00:00:00
# std_z_date_time                                    2021-10-01 10:35:00
# sta_z_date_time                                    2021-10-01 13:55:00
# etd_z_date_time                                    2021-10-01 11:00:00
# eta_z_date_time                                    2021-10-01 14:12:00
# atd_z                                                         11:02:00
# atd_z_date                                         2021-10-01 00:00:00
# atd_z_date_time                                    2021-10-01 11:02:00
# ata_z_date_time                                    2021-10-01 14:11:00
# sched_block                                                   03:20:00
# actual_block                                                  03:09:00
# block_difference                                                 -11.0
# std_z_weekend                                      2021-10-02 00:00:00
# std_z_monthyear                                    2021-10-01 00:00:00
# std_z_year                                                        2021
# sta_z_weekend                                      2021-10-02 00:00:00
# distance                                                          1283
# flight_type                                                          J
# flight_category                                                    NaN
# prim_dly                                                      00:19:00
# prim_c                                                             32B
# prim_c_desc          Late loaders; Lack of loading staff; Incorrect...
# dly1                                                          00:19:00
# c1_1                                                               32B
# c1_desc              Late loaders; Lack of loading staff; Incorrect...
# dly2                                                          00:08:00
# c2_1                                                               93R
# c2_desc              Applicable to all delays caused by late arriva...
# dly3                                                               NaN
# c3_1                                                               NaN
# c3_desc                                                            NaN
# dly4                                                               NaN
# c4_1                                                               NaN
# c4_desc                                                            NaN
# dly5                                                               NaN
# c5_1                                                               NaN
# c5_desc                                                            NaN
# dly6                                                               NaN
# c6_1                                                               NaN
# c6_desc                                                            NaN
# dly7                                                               NaN
# c7_1                                                               NaN
# c7_desc                                                            NaN
# dly8                                                               NaN
# c8_1                                                               NaN
# c8_desc                                                            NaN
# remarks                                                            NaN
# ttl_dep_dly                                                   00:27:00
# ttl_arr_dly                                                   00:16:00
# f_pax_rev                                                            0
# f_seats                                                              0
# j_pax_rev                                                           32
# j_seats                                                             32
# y_pax_rev                                                          282
# y_seats                                                            304
# ttl_pax_pad                                                        2.0
# ttl_fd_crew                                                          2
# ttl_cc_crew                                                         10
# ttl_ops_crew                                                        12
# ttl_pax_rev                                                        314
# ttl_seats                                                          336
# ttl_infants                                                          0
# ib_connex_pax_total                                                  1
# ob_connex_pax_total                                                 29
# lcl_joining_pax_ttl                                                313
# lcl_term_pax_ttl                                                   285
# arr_fuel                                                          5500
# dep_fuel                                                         20500
# cargo                                                                0
# mails                                                                0
# payload                                                          34138
# bags_kgs                                                          9105
# fuel_remaining                                                  6300.0
# arrival_fuel                                                    5500.0

# %%
df.dtypes.value_counts()
# Out:
# object            33
# int64             24
# float64           16
# datetime64[ns]    12
# dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
df.dropna(axis=1, how='all', inplace=True)
df.drop('ttl_infants', axis=1, inplace=True)
df.drop('std_z_year', axis=1, inplace=True)

# %% [markdown]
# ## Fixing Target

# %%
## fixing the departure and arrival delay in minutes
df['ttl_dep_dly_fix'] = (df['atd_z_date_time'] - df['std_z_date_time']).transform(lambda x: x.total_seconds()/60)
df['ttl_arr_dly_fix'] = (df['ata_z_date_time'] - df['sta_z_date_time']).transform(lambda x: x.total_seconds()/60)
# df['ttl_dep_dly_fix'] = [x.hour * 60 + x.minute for x in df['ttl_dep_dly']]
# df['ttl_arr_dly_fix'] = [x.hour * 60 + x.minute if x is not np.nan else np.nan for x in df['ttl_arr_dly']]

## target. on-time if it actual departed within 15 minutes of scheduled departure.
df['otp'] = np.where((df['ttl_dep_dly_fix'] > 15), 0, 1)

# %%
## There are some that did not depart
df['departed'] = np.where(~df['atd_z_date_time'].isnull(), 1, 0)

## Passenger Flights
df['passenger'] = [1 if x == 'J' else 0 for x in df['flight_type']]

# %%
## Routes
df['route'] = df['sched_dep_iata'] + '-' + df['sched_arr_iata']

## Bucketting distances according to quadrants
df['flight_distance'] = pd.cut(
    df.query('passenger==1 & departed==1')['distance'],
    5, labels=["ultrashort", "short", "medium", "long", "ultralong"])

## unique id
df['unique_id'] = (df['flight_number'] + '-' + df['schd_dep_date'].dt.strftime('%Y-%m-%d') + '-' +df['route'])

## Fixing Empty Seats
df['ttl_seats'] = df['ttl_seats'].groupby(df['sub_fleet']).transform('max') ## fillna missing ttl_seats by sub_fleet
df['ttl_seats'].fillna(0, inplace=True)

# %%
target = 'otp'
num = [x for x in df.columns if df.dtypes[x] in ('float', 'int')]
cat = [x for x in df.columns if df.dtypes[x] == 'object']
tim = [x for x in df.columns if df.dtypes[x] == 'datetime64[ns]']
num.remove(target)

# %%
ps = df.query('passenger==1 & departed==1').reset_index(drop=True).copy()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(ps, test_size=.2, random_state=0)

# %% [markdown]
# # Explore

# %% [markdown]
# ## Summary Notes
# - Currently, OTP for passenger flights are at 71%.
# - Out of all 215 flights that experienced delay, 31 are within our control.
# - By focusing on these, we can improve OTP by 75%.
#
# Notes:
# - Data excludes flights that does not have departure data.
# - Data only includes Passenger Flights.
# - There are some passenger_flights that flew even though ttl_seats=0. I have filled this value referencing the total expected seats of the sub_fleet.
# - ttl_dep_dly is wrong. Calculating manually using sched dep minus actual dep. Same for arrival.

# %%
corr = ps.corr()
corr[target].sort_values(ascending=False)
# Out:
# C:\Users\twelvefive\AppData\Local\Temp\ipykernel_15820\2442207167.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = ps.corr()
# otp                    1.000000
# ttl_fd_crew            0.061870
# distance               0.044979
# f_seats                0.043119
# f_pax_rev              0.027675
# block_difference       0.027079
# dep_fuel               0.013922
# mails                 -0.002803
# arrival_fuel          -0.006845
# ib_connex_pax_total   -0.011973
# ttl_ops_crew          -0.016958
# ttl_cc_crew           -0.040046
# ttl_pax_pad           -0.051233
# cargo                 -0.078458
# arr_fuel              -0.090981
# j_seats               -0.098023
# ttl_seats             -0.114550
# fuel_remaining        -0.115689
# y_seats               -0.122710
# lcl_term_pax_ttl      -0.136984
# ob_connex_pax_total   -0.155201
# j_pax_rev             -0.155850
# bags_kgs              -0.214073
# lcl_joining_pax_ttl   -0.231287
# y_pax_rev             -0.231902
# ttl_pax_rev           -0.238825
# payload               -0.240344
# ttl_arr_dly_fix       -0.592944
# ttl_dep_dly_fix       -0.711498
# departed                    NaN
# passenger                   NaN
# Name: otp, dtype: float64

# %% [markdown]
# ## Delay Codes

# %%
def stackDelay(frame, label, value):
    crs = []
    for x, y in zip(label, value):
        elm = frame[['unique_id', x, y]].pivot_table(values=y, index='unique_id', columns=x, aggfunc='sum')
        elm = elm.stack().reset_index()
        elm.columns = ['unique_id', 'Code', 'value']
        crs.append(elm)
    
    submit = pd.concat(crs, ignore_index=True)
    submit['value'] = [x.hour * 60 + x.minute for x in submit['value']]
    return submit

err_code = ['c1_1','c2_1', 'c3_1','c4_1']
err_dly = ['dly1','dly2', 'dly3','dly4']
err_desc = ['c1_desc','c2_desc', 'c3_desc','c4_desc']
delay_info = err_code + err_dly + err_desc

flight_dly = stackDelay(ps, err_code, err_dly)

# %%
flight_dly = flight_dly.join(delay_codes.set_index('Code'), on='Code')
flight_dly = flight_dly.pivot_table(index='unique_id', values='value'
                              , columns='Controllable', aggfunc='sum', fill_value=0)
flight_dly['tally_dep_dly'] = flight_dly["N"] + flight_dly["Y"]

# %%
ps = ps.join(flight_dly, on='unique_id')

ps[['N', 'Y', 'tally_dep_dly']] = ps[['N', 'Y', 'tally_dep_dly']].fillna(0)

ps['otp_max'] = np.where((ps['N'] > 15), 0, 1)

# %%
ps.groupby(['otp', 'otp_max'])['otp'].count()
# Out:
# otp  otp_max
# 0    0          184
#      1           31
# 1    1          529
# Name: otp, dtype: int64

# %%
ps['otp_max'].mean()
# Out:
# 0.7526881720430108

# %%
ps['otp'].mean()
# Out:
# 0.7110215053763441

# %% [markdown]
# ## Understanding Delay Codes

# %%
delc = stackDelay(ps, err_code, err_dly)

# %%
delc = delc.join(delay_codes.set_index('Code'), on='Code')

# %%
delc.head()
# Out:
#                    unique_id Code  value  \
# 0  OP0005-2021-10-07-AUH-MUC  03A      2
# 1  OP0005-2021-10-10-AUH-MUC  87B     19
# 2  OP0005-2021-10-27-AUH-MUC  89B      4
# 3  OP0005-2021-10-30-AUH-MUC  89B      5
# 4  OP0006-2021-10-02-MUC-AUH  03A      3
#
#                                               Reason OTP Working Group  \
# 0   Other - Flight departure within 3 minutes of STD            Others
# 1  Airport/Govt Authorities - Airport IT system m...           AptAuth
# 2  Airport/Govt Authorities - Awaiting start-up a...           AptAuth
# 3  Airport/Govt Authorities - Awaiting start-up a...           AptAuth
# 4   Other - Flight departure within 3 minutes of STD            Others
#
#   Controllable
# 0            N
# 1            N
# 2            N
# 3            N
# 4            N

# %%
delc.groupby(['Controllable','Code', 'Reason'])['value'].count().sort_values(ascending=False)['N']
# Out:
# Code  Reason
# 93R   Reactionary - Late aircraft rotation due Other                                          101
# 89B   Airport/Govt Authorities - Awaiting start-up and/or pushback clearance                   94
# 03A   Other - Flight departure within 3 minutes of STD                                         75
# 16I   Pax & Bag - Guest boarding                                                               34
# 16H   Pax & Bag - Guest settling on board                                                      32
# 86B   Airport/Govt Authorities - CIH authorities                                               29
# 91R   Reactionary - Awaiting guest and/or baggage from another late inbound Etihad flight      23
# 40A   Technical - Defects identified during transit (other than cabin/IFE items)               17
# 16J   Pax & Bag - Special needs handling                                                       14
# 85B   Airport/Govt Authorities - Airport/Government security authorities                       11
# 87A   Airport/Govt Auth - Airport terminal infrastructure/congestion limitations               11
# 10C   Pax & Bag - Acceptance of guests after flight closure for abnormal ops                   10
# 16D   Pax & Bag - Medical or personal offload / Medical assessment                              9
# 86A   Airport/Govt Authorities - Customs, immigration, health guests and baggage                9
# 32A   Aircraft & Ramp - Special/Bulky load handling                                             7
# 81A   Air Traffic Flow Management Restrictions - En-route ATC congestion                        6
# 16B   Pax & Bag - Guest convenience                                                             6
# 92R   Reactionary - Guest check-in error at originating station                                 5
# 77A   Weather - Ground handling impaired by adverse weather                                     5
# 09A   Other - Insufficient scheduled ground time due base schedule                              5
# 49A   Technical - APU inoperative (notified in advance) / engine start on stand                 4
# 42B   Technical - Tech documentation/personnel issues during scheduled maint                    4
# 55A   Localised Failure/Slow response of DCS / check-in system outage/latency                   3
# 89A   Airport/Govt Authorities - Restrictions at airport of departure                           3
# 35B   Aircraft & Ramp - Special aircraft cleaning requirements                                  3
# 16G   Pax & Bag - Voluntary Guest Offload                                                       3
# 16F   Pax & Bag - Guest seating                                                                 3
# 16E   Pax & Bag - Abnormal guest handling                                                       3
# 16A   Pax & Bag - Commercial publicity, VIP, press handling                                     3
# 91B   Reactionary - Awaiting baggage from another late inbound Etihad flight                    2
# 87E   Airport/Govt Authorities - Airport facility equipment malfunctions                        2
# 96R   Reactionary - Aircraft changes for reasons other than Technical                           2
# 87B   Airport/Govt Authorities - Airport IT system malfunctions                                 2
# 24B   Cargo & Mail - Incorrect contour/build of ULD                                             2
# 23B   Cargo & Mail - Late acceptance of cargo for commercial reasons                            2
# 21B   Cargo & Mail - Late or incorrect documentation for booked cargo and mail                  2
# 62C   Crew - Late alteration of load due to operational requirement                             2
# 58A   Failure of airline's communication systems at airport                                     2
# 55C   Airline DCS/Load control system outage/malfunctions                                       2
# 22B   Cargo & Mail - Late/Lack of manpower and/or servicing equipment in cargo warehouse        2
# 55B   Network Failure/Slow response of DCS / check-in system outage/latency                     2
# 72A   Weather - Destination Station below operating limits                                      1
# 99A   Miscellaneous - No suitable code                                                          1
# 96O   Reactionary - Abnormal operations                                                         1
# 87D   Airport/Govt Authorities - Airside facility limitations                                   1
# 86U   Airport/Govt Authorities - CBP authorities                                                1
# 06B   Gate/Stand Availability                                                                   1
# 71A   Weather - Departure Station below operating limits / ambient conditions change            1
# 63B   Crew - Delayed crew/loadmaster due ground transportation/airport congestion               1
# 63A   Crew - Late crew boarding (other than standby)                                            1
# 62A   Crew - Late/Change fuel notification from flight deck                                     1
# 41B   Technical - Defects identified during transit (cabin items)                               1
# 38A   Aircraft & Ramp - Lack of or unserviceable ULDs/pallets                                   1
# 21C   Cargo & Mail - Late or incorrect NOTOC for booked cargo/special loads                     1
# 21A   Cargo & Mail - Late or incorrect load figures for booked cargo and mail                   1
# 09B   Other - Insufficient scheduled ground time due NOC initiated aircraft / time changes      1
# Name: value, dtype: int64

# %%
(delc.groupby(['Controllable','OTP Working Group', 'Reason'])['value']
 .agg(['count', 'sum', 'mean'])
 .sort_values(by=['Controllable', 'OTP Working Group', 'count'], ascending=False)).loc['Y']
# Out:
#                                                                       count  \
# OTP Working Group Reason
# Others            Other - No delay code received in NEO                   7
#                   Unassigned                                              1
# Below Wing        Aircraft & Ramp - Errors or late/lack of loadin...     16
#                   Pax & Bag - Late or incorrectly sorted transfer...     15
#                   Aircraft & Ramp - Late or lack of loading equip...      8
#                   Cargo & Mail - Late/Lack of manpower and/or gro...      6
#                   Pax & Bag - Late or incorrectly sorted local ba...      5
#                   Aircraft & Ramp - Fuelling/Defuelling                   2
#                   Aircraft & Ramp - Late or lack of servicing equ...      1
#                   Aircraft & Ramp - Late or lack of technical ram...      1
#                   Aircraft & Ramp - Slow fuelling                         1
# Above Wing        Airport/Govt Authorities - Mandatory security g...      5
#                   Pax & Bag - Paging/Missing checked-in guest wit...      5
#                   Pax & Bag - Handluggage issues during boarding          4
#                   Pax & Bag - Check in error                              2
#                   Late Check-in                                           1
#                   Pax & Bag - Acceptance of guests after flight c...      1
#
#                                                                       sum  \
# OTP Working Group Reason
# Others            Other - No delay code received in NEO               136
#                   Unassigned                                           14
# Below Wing        Aircraft & Ramp - Errors or late/lack of loadin...  244
#                   Pax & Bag - Late or incorrectly sorted transfer...  185
#                   Aircraft & Ramp - Late or lack of loading equip...  198
#                   Cargo & Mail - Late/Lack of manpower and/or gro...   85
#                   Pax & Bag - Late or incorrectly sorted local ba...   56
#                   Aircraft & Ramp - Fuelling/Defuelling                34
#                   Aircraft & Ramp - Late or lack of servicing equ...    8
#                   Aircraft & Ramp - Late or lack of technical ram...    8
#                   Aircraft & Ramp - Slow fuelling                      31
# Above Wing        Airport/Govt Authorities - Mandatory security g...   66
#                   Pax & Bag - Paging/Missing checked-in guest wit...   58
#                   Pax & Bag - Handluggage issues during boarding       37
#                   Pax & Bag - Check in error                           16
#                   Late Check-in                                        24
#                   Pax & Bag - Acceptance of guests after flight c...   18
#
#                                                                            mean
# OTP Working Group Reason
# Others            Other - No delay code received in NEO               19.428571
#                   Unassigned                                          14.000000
# Below Wing        Aircraft & Ramp - Errors or late/lack of loadin...  15.250000
#                   Pax & Bag - Late or incorrectly sorted transfer...  12.333333
#                   Aircraft & Ramp - Late or lack of loading equip...  24.750000
#                   Cargo & Mail - Late/Lack of manpower and/or gro...  14.166667
#                   Pax & Bag - Late or incorrectly sorted local ba...  11.200000
#                   Aircraft & Ramp - Fuelling/Defuelling               17.000000
#                   Aircraft & Ramp - Late or lack of servicing equ...   8.000000
#                   Aircraft & Ramp - Late or lack of technical ram...   8.000000
#                   Aircraft & Ramp - Slow fuelling                     31.000000
# Above Wing        Airport/Govt Authorities - Mandatory security g...  13.200000
#                   Pax & Bag - Paging/Missing checked-in guest wit...  11.600000
#                   Pax & Bag - Handluggage issues during boarding       9.250000
#                   Pax & Bag - Check in error                           8.000000
#                   Late Check-in                                       24.000000
#                   Pax & Bag - Acceptance of guests after flight c...  18.000000

# %%
delay_codes
# Out:
#     Code                                             Reason OTP Working Group  \
# 0    03A   Other - Flight departure within 3 minutes of STD            Others
# 1    04A              Other - No delay code received in NEO            Others
# 2    04B           Other - TAS/Dispatcher poor coordination               NOC
# 3    04C  Other - Technical inefficient/lack of communic...         Technical
# 4    05B  Other - Standby delay code while delay reason ...            Others
# ..   ...                                                ...               ...
# 161  96O                  Reactionary - Abnormal operations               NOC
# 162  96R  Reactionary - Aircraft changes for reasons oth...               NOC
# 163  96T  Reactionary - Non-Mandatory Technical Defect R...               NOC
# 164  99A                   Miscellaneous - No suitable code            Others
# 165  XXX                                         Unassigned            Others
#
#     Controllable
# 0              N
# 1              Y
# 2              Y
# 3              Y
# 4              N
# ..           ...
# 161            N
# 162            N
# 163            N
# 164            N
# 165            Y
#
# [166 rows x 4 columns]

# %% [markdown]
# # Submission

# %%
ps.to_csv('submission.csv', index=False)
